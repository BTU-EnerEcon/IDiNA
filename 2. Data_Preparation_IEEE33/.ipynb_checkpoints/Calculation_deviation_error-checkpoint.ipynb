# %%
import numpy as np
import pandas as pd

########################################part 1#####################################
#erzeugen der Prognosefehler

#  Profil für Anzahl der Zeitschritte
df_profil = pd.read_excel("profil_case_study.xlsx")

# Anzahl der Zufallsvariablen pro Zeitpunkt
num_variables = 32

# Anzahl der Szenarien
num_scenarios = 100

# Standardabweichung der normalverteilten Zufallsvariablen in MW
# standarddeviation SLP from real
std_dev = 0.1196

# Erstelle ein leeres Pandas-DataFrame für die Ergebnisse
results = pd.DataFrame()

# Für jedes Szenario:   
for i in range(num_scenarios):
    # Erstelle ein Array mit normalverteilten Zufallsvariablen für jeden Bus und jeden Zeitpunkt
    random_variables = np.random.normal(0, std_dev, (len(df_profil), num_variables))
    
    # Berechne die Summe der Zufallsvariablen für jeden Zeitpunkt
    sum_random_variables = np.sum(random_variables, axis=1)
       
    # Berechne den Faktor, um den jede Zufallsvariable angepasst werden muss, damit die Summe 0 ergibt
    factor = -sum_random_variables / num_variables

    # Passe jede Zufallsvariable an, indem der Faktor multipliziert wird
    random_variables_adjusted = random_variables + factor.reshape(-1, 1)

    # Die gewünschte Toleranz weil die Berechnung von Gleitkommazahlen ungenau ist und somit die Summe der angepassten Zufallszahlen minimal von 0 abweichen kann
    tolerance = 1e-10

    # Prüfe, ob die Summe der angepassten Zufallsvariablen für jeden Zeitpunkt innerhalb der Toleranz ist
    assert np.allclose(np.sum(random_variables_adjusted, axis=1), 0, atol=tolerance)
    
    # Füge die Zufallsvariablen ein
    df_varied = pd.DataFrame(random_variables_adjusted)
    
    # Füge eine Spalte für den Slack bus hinzu
    df_varied.insert(0, '1',  0)

    # Füge eine Spalte für den Zeitpunkt hinzu
    df_varied.insert(0, "t", range(1, len(df_profil)+1))
    
    # Benenne die Spalten von 1 bis 33
    df_varied.columns = ["t", 1] + list(range(2, num_variables+2))
    
    # Füge das DataFrame mit den angepassten Zufallsvariablen dem DataFrame der Ergebnisse hinzu
    results = pd.concat([results, df_varied], ignore_index=True)

# Füge eine Spalte für die Szenarien hinzu
results.insert(0, "s", np.repeat(np.arange(1, num_scenarios+1), len(df_profil)))

# Sortiere die Ergebnisse nach Szenario und Zeitpunkt
results = results.sort_values(by=["s", "t"])

# Speichere das DataFrame der Ergebnisse in einer CSV-Datei
results.to_excel("load_deviation_SLP.xlsx", index=False)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# File C:\Miniconda\lib\site-packages\pandas\io\formats\excel.py:916, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     915 try:
# --> 916     writer._write_cells(
#     917         formatted_cells,
#     918         sheet_name,
#     919         startrow=startrow,
#     920         startcol=startcol,
#     921         freeze_panes=freeze_panes,
#     922     )
#     923 finally:
#     924     # make sure to close opened file handles
#
# File C:\Miniconda\lib\site-packages\pandas\io\excel\_openpyxl.py:493, in OpenpyxlWriter._write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     492 for cell in cells:
# --> 493     xcell = wks.cell(
#     494         row=startrow + cell.row + 1, column=startcol + cell.col + 1
#     495     )
#     496     xcell.value, fmt = self._value_with_fmt(cell.val)
#
# File C:\Miniconda\lib\site-packages\openpyxl\worksheet\worksheet.py:240, in Worksheet.cell(self, row, column, value)
#     238     raise ValueError("Row or column values must be at least 1")
# --> 240 cell = self._get_cell(row, column)
#     241 if value is not None:
#
# File C:\Miniconda\lib\site-packages\openpyxl\worksheet\worksheet.py:257, in Worksheet._get_cell(self, row, column)
#     256     cell = Cell(self, row=row, column=column)
# --> 257     self._add_cell(cell)
#     258 return self._cells[coordinate]
#
# File C:\Miniconda\lib\site-packages\openpyxl\worksheet\worksheet.py:268, in Worksheet._add_cell(self, cell)
#     267 self._current_row = max(row, self._current_row)
# --> 268 self._cells[(row, column)] = cell
#
# MemoryError:
#
# During handling of the above exception, another exception occurred:
#
# MemoryError                               Traceback (most recent call last)
# Cell In [2], line 65
#      62 results = results.sort_values(by=["s", "t"])
#      64 # Speichere das DataFrame der Ergebnisse in einer CSV-Datei
# ---> 65 results.to_excel("load_deviation_SLP.xlsx", index=False)
#
# File C:\Miniconda\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\Miniconda\lib\site-packages\pandas\util\_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File C:\Miniconda\lib\site-packages\pandas\core\generic.py:2374, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes, storage_options)
#    2361 from pandas.io.formats.excel import ExcelFormatter
#    2363 formatter = ExcelFormatter(
#    2364     df,
#    2365     na_rep=na_rep,
#    (...)
#    2372     inf_rep=inf_rep,
#    2373 )
# -> 2374 formatter.write(
#    2375     excel_writer,
#    2376     sheet_name=sheet_name,
#    2377     startrow=startrow,
#    2378     startcol=startcol,
#    2379     freeze_panes=freeze_panes,
#    2380     engine=engine,
#    2381     storage_options=storage_options,
#    2382 )
#
# File C:\Miniconda\lib\site-packages\pandas\io\formats\excel.py:926, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options)
#     923 finally:
#     924     # make sure to close opened file handles
#     925     if need_save:
# --> 926         writer.close()
#
# File C:\Miniconda\lib\site-packages\pandas\io\excel\_base.py:1480, in ExcelWriter.close(self)
#    1478 def close(self) -> None:
#    1479     """synonym for save, to make it more file-like"""
# -> 1480     self._save()
#    1481     self._handles.close()
#
# File C:\Miniconda\lib\site-packages\pandas\io\excel\_openpyxl.py:109, in OpenpyxlWriter._save(self)
#     105 def _save(self) -> None:
#     106     """
#     107     Save workbook to disk.
#     108     """
# --> 109     self.book.save(self._handles.handle)
#     110     if "r+" in self._mode and not isinstance(self._handles.handle, mmap.mmap):
#     111         # truncate file to the written content
#     112         self._handles.handle.truncate()
#
# File C:\Miniconda\lib\site-packages\openpyxl\workbook\workbook.py:407, in Workbook.save(self, filename)
#     405 if self.write_only and not self.worksheets:
#     406     self.create_sheet()
# --> 407 save_workbook(self, filename)
#
# File C:\Miniconda\lib\site-packages\openpyxl\writer\excel.py:293, in save_workbook(workbook, filename)
#     291 archive = ZipFile(filename, 'w', ZIP_DEFLATED, allowZip64=True)
#     292 writer = ExcelWriter(workbook, archive)
# --> 293 writer.save()
#     294 return True
#
# File C:\Miniconda\lib\site-packages\openpyxl\writer\excel.py:275, in ExcelWriter.save(self)
#     273 def save(self):
#     274     """Write data into the archive."""
# --> 275     self.write_data()
#     276     self._archive.close()
#
# File C:\Miniconda\lib\site-packages\openpyxl\writer\excel.py:75, in ExcelWriter.write_data(self)
#      72 else:
#      73     archive.writestr(ARC_THEME, theme_xml)
# ---> 75 self._write_worksheets()
#      76 self._write_chartsheets()
#      77 self._write_images()
#
# File C:\Miniconda\lib\site-packages\openpyxl\writer\excel.py:215, in ExcelWriter._write_worksheets(self)
#     212 for idx, ws in enumerate(self.workbook.worksheets, 1):
#     214     ws._id = idx
# --> 215     self.write_worksheet(ws)
#     217     if ws._drawing:
#     218         self._write_drawing(ws._drawing)
#
# File C:\Miniconda\lib\site-packages\openpyxl\writer\excel.py:200, in ExcelWriter.write_worksheet(self, ws)
#     198 else:
#     199     writer = WorksheetWriter(ws)
# --> 200     writer.write()
#     202 ws._rels = writer._rels
#     203 self._archive.write(writer.out, ws.path[1:])
#
# File C:\Miniconda\lib\site-packages\openpyxl\worksheet\_writer.py:359, in openpyxl.worksheet._writer.WorksheetWriter.write()
#
# File C:\Miniconda\lib\site-packages\openpyxl\worksheet\_writer.py:123, in openpyxl.worksheet._writer.WorksheetWriter.write_rows()
#
# File C:\Miniconda\lib\site-packages\openpyxl\worksheet\_writer.py:124, in openpyxl.worksheet._writer.WorksheetWriter.write_rows()
#
# File C:\Miniconda\lib\site-packages\openpyxl\worksheet\_writer.py:110, in openpyxl.worksheet._writer.WorksheetWriter.rows()
#
# MemoryError:
