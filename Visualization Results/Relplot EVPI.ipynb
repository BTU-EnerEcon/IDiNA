# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
sns.set_theme(style="darkgrid")

# Load an example dataset with long-form data
costs = pd.read_excel("Seaborn_input_winter.xlsx")

# Plot the responses for different events and regions
graph=sns.lineplot(x="S", y="Values",
             hue="Case",dashes=True,palette="flare",
             data=costs)

# Set x-axis ticks
x_ticks = range(1, 1001, 100)
graph.set_xticks([0] + list(x_ticks) + [1000])
graph.set_xticklabels([''] + ['s{}'.format(i) for i in x_ticks] + ['s1000'])

plt.legend(loc= "upper left", bbox_to_anchor=(1, 1))

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

sns.set_theme(style="whitegrid")

# Load the example tips dataset
data = pd.read_excel("Seaborn_input_seasons_relativ.xlsx")

# Draw a nested violinplot and split the violins for easier comparison
sns.violinplot(data=data, x="Season", y="EVPI in % of Total System Costs", scale="width",palette="Greys",scale_hue=True,
                inner=None, linewidth=1
               )
#sns.swarmplot(x ="Season", y ="Points",data=data, size=1.3,palette = "RdBu_r", hue="Scenario")
#sns.boxplot(x ="Season", y ="EVPI in % of Total System Costs",data=data,palette = "RdBu_r", hue="Scenario")
sns.stripplot(x ="Season", y ="EVPI in % of Total System Costs",data=data,palette = "RdBu_r", hue="Scenario",size=1.5, jitter=0.01)
#sns.color_palette(palette = "RdBu",reverse=True)
plt.legend(loc= "upper left", bbox_to_anchor=(0, 1),fontsize = 10)
#sns.boxenplot(data=data, x="Season", y="EVPI in % of Total System Costs", color="red", width=0.05)
#figure size
sns.set(rc={"figure.figsize":(8, 5)})
plt.xlabel("Season", size=16)
plt.ylabel("EVPI in % of Total System Costs", size=16)
#sns.plotting_context()
sns.despine(left=True)

# %%
sns.set_theme(style="whitegrid")

# Load the example tips dataset
data = pd.read_excel("Seaborn_input_seasons_relativ.xlsx")

# Draw a nested violinplot and split the violins for easier comparison
sns.boxenplot(data=data, x="Season", y="EVPI in % of Total System Costs",palette="rocket_r", scale="area",
                 linewidth=1
               )
#figure size
sns.set(rc={"figure.figsize":(8, 5)})
plt.xlabel("Season", size=16)
plt.ylabel("EVPI in % of Total System Costs", size=16)
#sns.plotting_context()
sns.despine(left=True)

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

data = pd.read_excel("Seaborn_input_seasons_relativ.xlsx")

f, ax = plt.subplots(figsize=(7, 5))
sns.despine(f)

sns.histplot(
    data,
    x="EVPI in % of Total System Costs", hue="Season",
    multiple="stack",
    palette="rocket_r",
    edgecolor=".3",
    linewidth=.5,
    stat="count",
    log_scale=False,
    #binwidth=1,
    #kde=True
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
#ax.set_xticks([25, 50, 75, 100])

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_theme(style="white", rc={"axes.facecolor": (0, 0, 0, 0)})

# Create the data
data = pd.read_excel("Seaborn_input_seasons_relativ.xlsx")

# Initialize the FacetGrid object
pal = sns.cubehelix_palette(10, rot=-.25, light=.7)
g = sns.FacetGrid(data, row="Season", hue="Season", aspect=3, height=1.5, palette="rocket")

# Draw the densities in a few steps
g.map(sns.kdeplot, "EVPI in % of Total System Costs",
      bw_adjust=0.25, clip_on=False,log_scale =True,
      fill=True, alpha=1, linewidth=1.5)
#g.map(sns.kdeplot, "EVPI in % of Total System Costs", clip_on=False, color="w", lw=2, bw_adjust=.25)

# passing color=None to refline() uses the hue mapping
g.refline(y=0, linewidth=2, linestyle="-", color=None, clip_on=False)


# Define and use a simple function to label the plot in axes coordinates
def label(x, color, label):
    ax = plt.gca()
    ax.text(0, .5, label, fontweight="bold", color=color,
            ha="left", va="center", transform=ax.transAxes)


g.map(label, "EVPI in % of Total System Costs")

# Set the subplots to overlap
g.figure.subplots_adjust(hspace=-.25)

# Remove axes details that don't play well with overlap
g.set_titles("")
g.set(yticks=[], ylabel="")
g.despine(bottom=True, left=True)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")
values = pd.read_excel("Seaborn_input_seasons_relativ.xlsx")

sns.kdeplot(
   data=values, x="EVPI in % of Total System Costs", hue="Season",
   fill=True, common_norm=True, palette="rocket",log_scale =True,
   alpha=0.5, linewidth=1
)

#plt.legend(title='Distribution of EVPI', loc='upper right', labels="Season")
# Out:
# <AxesSubplot:xlabel='EVPI in % of Total System Costs', ylabel='Density'>
